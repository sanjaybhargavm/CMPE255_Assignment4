# %%
# !pip install autoviml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 133 kB 8.5 MB/s
# ...
#      |████████████████████████████████| 255.9 MB 40 kB/s
# ...
#      |████████████████████████████████| 569 kB 52.2 MB/s
# ...
#      |████████████████████████████████| 240 kB 46.7 MB/s
# ...
#      |████████████████████████████████| 76.6 MB 1.4 MB/s
# ...
#      |████████████████████████████████| 125 kB 60.5 MB/s
# ...
#      |████████████████████████████████| 268 kB 55.7 MB/s
# ...
#      |████████████████████████████████| 11.2 MB 51.4 MB/s
# ...
#      |████████████████████████████████| 965 kB 47.7 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 57.0 MB/s
# ...
#      |████████████████████████████████| 121 kB 57.9 MB/s
# ...
#      |████████████████████████████████| 83 kB 161 kB/s
# ...
#   Created wheel for emoji: filename=emoji-2.2.0-py3-none-any.whl size=234927 sha256=aeaa7b3304e307c5c0ba489ed16380ceb2f15126744c1a997455990cd7134c4a
# ...

# %%
from autoviml.Auto_ViML import Auto_ViML

import pandas as pd
# Out:
# Imported Auto_ViML version: 0.1.710. Call using:
#              m, feats, trainm, testm = Auto_ViML(train, target, test,
#                             sample_submission='',
#                             scoring_parameter='', KMeans_Featurizer=False,
#                             hyper_param='RS',feature_reduction=True,
#                              Boosting_Flag='CatBoost', Binning_Flag=False,
#                             Add_Poly=0, Stacking_Flag=False,Imbalanced_Flag=False,
#                             verbose=1)
#
#
# Imported Auto_NLP version: 0.1.01.. Call using:
#      train_nlp, test_nlp, nlp_pipeline, predictions = Auto_NLP(
#                 nlp_column, train, test, target, score_type='balanced_accuracy',
#                 modeltype='Classification',top_num_features=200, verbose=0,
#                 build_model=True)
# <style>.container { width:95% !important; }</style>

# %%
data = pd.read_csv('/content/housing.csv')

# %%
target = 'housing_median_age'
m, feats, trainm, testm = Auto_ViML(data, target,
                            sample_submission='',
                            scoring_parameter='', KMeans_Featurizer=False,
                            hyper_param='RS',feature_reduction=True,
                             Boosting_Flag='XG', Binning_Flag=False,
                            Add_Poly=2, Stacking_Flag=True,Imbalanced_Flag=False,
                            verbose=1)
# Out:
# ##############  D A T A   S E T  A N A L Y S I S  #######################
# Training Set Shape = (20640, 10)
#     Training Set Memory Usage = 1.57 MB
# Single_Label Target: ['housing_median_age']
#
# ################ Regression VISUALIZATION Started #####################
# No shuffling of data set before training...
#     Using RandomizedSearchCV for Hyper Parameter Tuning. This is 3X faster than GridSearchCV...
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  8
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  1
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
# ...

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
y_true = data[target].values
y_pred = testm[target+'_predictions'].values
print(y_true.shape, y_pred.shape)
# Out:
# (20640,) (20640,)
